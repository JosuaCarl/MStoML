# %%
import pandas as pd

# %%
df = pd.read_excel("../../data/comm8_self/Map_index_codes.xlsx")

# %%
df.loc[9:60]
# Out:
#    Index code       Sample name  \
# 9     msAV254    COM7_extract_1
# 10    msAV255    COM7_extract_2
# 11    msAV256    COM7_extract_3
# 12    msAV257    COM7_extract_4
# 13    msAV258    COM7_extract_5
# 14    msAV259    COM7_extract_6
# 15    msAV260    COM7_extract_7
# 16    msAV261    COM7_extract_8
# 17    msAV262    BacCom_extract
# 18    msAV263     TCOM6_extract
# 19    msAV264   TCOM5_extract_1
# 20    msAV265   TCOM5_extract_2
# 21    msAV266   TCOM5_extract_3
# 22    msAV267   TCOM5_extract_4
# 23    msAV268   TCOM5_extract_5
# 24    msAV269   TCOM4_extract_1
# 25    msAV270   TCOM4_extract_2
# 26    msAV271   TCOM4_extract_3
# 27    msAV272   TCOM4_extract_4
# 28    msAV273   TCOM4_extract_5
# 29    msAV274   TCOM4_extract_6
# 30    msAV275   TCOM4_extract_7
# 31    msAV276   TCOM4_extract_8
# 32    msAV277   TCOM4_extract_9
# 33    msAV278  TCOM4_extract_10
# 34    msAV279     UCOM6_extract
# 35    msAV280   UCOM5_extract_1
# 36    msAV281   UCOM5_extract_2
# ...
